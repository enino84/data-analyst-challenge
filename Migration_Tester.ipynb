# %%
import seaborn as sns
import matplotlib.pyplot as plt
from connector import Connector

# %%
sql = "SELECT * FROM data_ LIMIT 10"
con = Connector()
df_ = con.execute_query(sql=sql)

# %%
sql = "SELECT * FROM women_in_government"
con = Connector()
df_ = con.execute_query(sql=sql)

# %%
import seaborn as sns
plt.figure(figsize=(40, 6))
sns.lineplot(data=df_, x='date', y='valueInThousands')
plt.xticks(rotation=90);

# %%
sql = "SELECT * FROM ratio_evolution_pro_sup"
con = Connector()
df_ = con.execute_query(sql=sql)

# %%
import seaborn as sns
plt.figure(figsize=(40, 6))
sns.lineplot(data=df_, x='date', y='ratioInThousands')
plt.xticks(rotation=90);
